# %%
# for this model we need to ony signin to ollama and then we can use it without any additional setup,download or configuration. It is a great model for testing and experimentation.
import ollama
response=ollama.generate(model="glm-5:cloud", prompt="What is the capital of France?")
print(response['response'])
# Out:
# The capital of France is **Paris**.
